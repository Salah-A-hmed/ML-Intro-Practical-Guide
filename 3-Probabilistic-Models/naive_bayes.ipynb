# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import CategoricalNB

df = pd.read_csv("tennis_dataset.csv")

le = LabelEncoder()
for col in df.columns:
    df[col] = le.fit_transform(df[col])

X = df.iloc[:, :-1]
y = df.iloc[:, -1]

model = CategoricalNB()
model.fit(X, y)

print("Prediction for sample 0:", model.predict([X.iloc[0]])[0])
print("Accuracy:", model.score(X, y))
# Out:
# Prediction for sample 0: 0
# Accuracy: 0.8888888888888888
# c:\Users\it legend\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but CategoricalNB was fitted with feature names
#   warnings.warn(
