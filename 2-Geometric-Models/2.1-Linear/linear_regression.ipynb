# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

df = pd.read_csv("hours_scores.csv")

X = df[["hours"]]
y = df["score"]

model = LinearRegression()
model.fit(X, y)

plt.scatter(X, y)
plt.plot(X, model.predict(X))
plt.xlabel("Hours")
plt.ylabel("Score")
plt.show()

print("Prediction for 7 hours:", model.predict([[7]])[0])
# Out:
# Prediction for 7 hours: 74.61818181818182
# c:\Users\it legend\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
